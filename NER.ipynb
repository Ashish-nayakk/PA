# %% [markdown]
# NER

# %%
#PROGRAM3:   NAMED ENTITY RECOGNITION---
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk, sent_tokenize

input = "Ashish kumar nayak has taken the data anlaytics and machine learning domain in INDIA . it will be the future."
ner = ne_chunk(pos_tag(word_tokenize(input)))
# print(ner)

from nltk.tree import Tree
named_entity = []
for subtree in ner:
    if isinstance(subtree, Tree):
        entity = "".join([token for token, pos in subtree.leaves()])
        named_entity.append(entity)
print(named_entity)
# Out:
# ['Ashish', 'INDIA']

# %%
pip install spacy
# Out:
# ...
#    ---------------------------------------- 0.0/13.9 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/13.9 MB 10.0 MB/s eta 0:00:02
#    -------- ------------------------------- 2.9/13.9 MB 8.3 MB/s eta 0:00:02
#    ------------ --------------------------- 4.5/13.9 MB 8.3 MB/s eta 0:00:02
#    ------------------- -------------------- 6.8/13.9 MB 8.9 MB/s eta 0:00:01
#    -------------------------- ------------- 9.2/13.9 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------ --- 12.6/13.9 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 13.9/13.9 MB 10.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/630.6 kB ? eta -:--:--
#    --------------------------------------- 630.6/630.6 kB 15.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 15.9 MB/s eta 0:00:00
# ...

# %%
python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 1.1 MB/s eta 0:00:12
#      --- ------------------------------------ 1.0/12.8 MB 1.4 MB/s eta 0:00:09
#      ---- ----------------------------------- 1.3/12.8 MB 1.5 MB/s eta 0:00:08
#      ----- ---------------------------------- 1.8/12.8 MB 1.7 MB/s eta 0:00:07
#      ------- -------------------------------- 2.4/12.8 MB 1.8 MB/s eta 0:00:06
#      --------- ------------------------------ 2.9/12.8 MB 2.0 MB/s eta 0:00:06
#      ------------ --------------------------- 3.9/12.8 MB 2.3 MB/s eta 0:00:04
#      -------------- ------------------------- 4.7/12.8 MB 2.5 MB/s eta 0:00:04
#      ----------------- ---------------------- 5.5/12.8 MB 2.6 MB/s eta 0:00:03
# ...

# %%
import spacy

# Load the installed English model
nlp = spacy.load("en_core_web_sm")

text = "Ashish kumar nayak has taken the data analytics and machine learning domain in INDIA. It will be the future."
doc = nlp(text)

# Extract and print named entities
named_entity = []
for ent in doc.ents:
    named_entity.append(ent.text)

print(named_entity)
# Out:
# ['Ashish', 'INDIA']
